# %%
import pandas as pd

# %%
import yfinance as yf

df = yf.download("^BVSP", start="2010-01-01")
# Out:
# /tmp/ipykernel_2068/1859978238.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("^BVSP", start="2010-01-01")
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
# Price            Close         High          Low         Open    Volume
# Ticker           ^BVSP        ^BVSP        ^BVSP        ^BVSP     ^BVSP
# Date
# 2010-01-04   70045.000   70081.0000   68587.0000   68587.0000   1655400
# 2010-01-05   70240.000   70595.0000   69928.0000   70046.0000   1984200
# 2010-01-06   70729.000   70937.0000   70016.0000   70237.0000   2243600
# 2010-01-07   70451.000   70723.0000   70045.0000   70723.0000   1555000
# 2010-01-08   70263.000   70766.0000   70158.0000   70455.0000   1634400
# ...                ...          ...          ...          ...       ...
# 2025-12-03  161755.000  161964.0000  161093.0000  161094.0000   8292000
# 2025-12-04  164456.000  164551.0000  161759.0000  161760.0000  10592300
# 2025-12-05  157369.000  165036.0000  157007.0000  164461.0000  14529000
# 2025-12-08  158187.000  159235.0000  157369.0000  157369.0000   9024100
# 2025-12-09  157981.125  158851.1875  155187.8125  158187.4375         0
#
# [3952 rows x 5 columns]

# %%
import yfinance as yf
import matplotlib.pyplot as plt

plt.figure(figsize=(16,7))
plt.plot(df.index, df["Close"], linewidth=1.5)
plt.title("Ibovespa (^BVSP) - Histórico de Fechamento", fontsize=16)
plt.xlabel("Ano", fontsize=12)
plt.ylabel("Fechamento (pontos)", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
plt.savefig("images/gráfico_teste.png", dpi=300, bbox_inches="tight")
